# %%
import xarray as xr

# %%
ts = xr.open_dataset("/rds/general/user/cb2714/home/00_WWA_project_folder/ephemeral/mg-floods/mswep_bas.nc").precip.to_dataframe()
ts.to_csv("pr-daily_bas_mswep.csv")
ts.resample("MS").sum().to_csv("pr-monthly_bas_mswep.csv")

# %%
ts = xr.open_dataset("/rds/general/user/cb2714/home/00_WWA_project_folder/ephemeral/mg-floods/bzgd_bas.nc").pr.to_dataframe()
ts.to_csv("pr-daily_bas_bzgd.csv")
ts.resample("MS").sum().to_csv("pr-monthly_bas_bzgd.csv")

# %%
ts = xr.open_dataset("/rds/general/user/cb2714/home/00_WWA_project_folder/ephemeral/mg-floods/chirps_bas.nc").precip.to_dataframe()
ts.to_csv("pr-daily_bas_chirps.csv")
ts.resample("MS").sum().to_csv("pr-monthly_bas_chirps.csv")

# %%
xr.open_dataset("/rds/general/user/cb2714/home/00_WWA_project_folder/ephemeral/mg-floods/cruts_bas.nc").pre.to_dataframe().to_csv("pr-monthly_bas_cruts.csv")

# %%
xr.open_dataset("/rds/general/user/cb2714/home/00_WWA_project_folder/ephemeral/mg-floods/gpccmon_bas.nc").precip.to_dataframe().to_csv("pr-monthly_bas_gpcc.csv")
