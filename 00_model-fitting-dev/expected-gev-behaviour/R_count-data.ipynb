# %%
set.seed(42)

x <- rnbinom(100, size = 1, prob = 1/30)
df <- data.frame(one = 1:length(x), x = x)
df$logx <- log(df$x)

# %%
plot(density(x))
# Out:
# Plot with title “density.default(x = x)”

# %%
fit <- glm(x ~ one, data = df, family = poisson)
logfit <- glm(logx ~ one, data = df

# %%
plot(hist(df$logx))
# Out:
# Plot with title “Histogram of df$logx”
